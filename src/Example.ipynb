# %%
# %load_ext autoreload
# %autoreload 2

# %%
import copy

# %%
from tda_digits import *

# %%
image = get_image(n=17, show=True)

# %%
binary_image = get_binary_image(image, show=True)

# %%
skeleton = get_skeleton(binary_image, show=True)

# %%
points = get_points(skeleton, sweep_direction='top', show=True)

# %%
points = get_points(skeleton, sweep_direction='bottom', show=True)

# %%
points = get_points(skeleton, sweep_direction='right', show=True)

# %%
points = get_points(skeleton, sweep_direction='left', show=True)

# %%
point_list = PointList(points)
emb_graph = point_list.get_emb_graph()
canvas = Canvas('Embedded graph')
draw_graph(canvas, emb_graph)
canvas.show()

# %%
simplices = get_simplices(emb_graph, show=True)

# %%
intervals = get_betti_barcodes(simplices)
draw_betti_barcodes(intervals, M)
# Out:
# Betti 0
# (8.0, inf)
# (12.0, 14.0)
#
# Betti 1
# (14.0, inf)
# (19.0, inf)
